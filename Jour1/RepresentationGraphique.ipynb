# %% [markdown]
# ## <p style=" color:navy;"> Représentations graphiques</p>

# %% [markdown]
# #### Le package matplotlib
# [site officiel](https://matplotlib.org/index.html)
# [un cours](https://courspython.com/introduction-courbes.html)
#
# Si le package n'est pas présent dans votre environnement il va donc falloir l'installer
#
# Pour connaître les modules déjà installés dans votre environnement vous pouvez utiliser l'installateur 'pip', module présent par défaut depuis Python 3.4,
# ``` python
# >>> pip list # renvoie la liste des packages déjà présents
# ```
#
# Si matplotlib n'est pas dans la liste il suffit de taper à partir de votre éditeur :
# ``` python
# >>> pip install matplotlib # va installer le module
# ```
# pylab est un module de matplolib. (on peut de même utiliser pyplot)

# %%
# Une fonction affine par morceaux.
from pylab import plot,show    # à partir du sous module pylab de matplotlib...
X = [0, 1, 2, 3, 4, 5]
# rappelez vous par compréhension nous aurions pu écrire : [k for k in range(0,6)]  
Y = [4, -3, 6, 2, 2, -4]
plot(X, Y)   # construit le nuage de points par correspondance des deux listes
show()   # comme son nom l'indique, nous montre le graphe

# %% [markdown]
# Ajoutons quelques agréments :
#
#     un titre avec title()
#     un nom de fonction avec label (ce n'est pas une fonction plutôt un attribut comme en html)
#     une légende avec légend()

# %%
# Une fonction affine par morceaux.
from pylab import plot,show, legend, title
X = [0, 1, 2, 3, 4, 5]    
Y = [4, -3, 6, 2, 2, -4]
plot(X, Y, label = "f")   # original comme nom non ?
legend()  # pour l'affichage
title('fonction affine par morceaux')
show()   # et tout cela va nous rendre ... suspense...

# %% [markdown]
# Rajouter dans la fonction plot couleur, type de tracés, type de points comme "r--x" r pour red, -- pour tirets et x pour le type de point.

# %% [markdown]
# **Exercice 1 ...**
# Le debut de programme suivant doit vous permettre de tracer les fonctions sinus et cosinus dans un même repère,
# A vous de le compléter, la fonction sinus doit être tracée en bleu en tirets (--), la fonction cosinus en rouge et pointilés (:), ajouter légende et le titre "fonctions trigonométriques"

# %%
from matplotlib.pylab import plot, arange, cos, sin, show, pi
X = arange(-2 * pi, pi, 0.01) # rappelez vous range n'est pas de type list, arange est l'équivalent de list(range())
# A vous ...

# %% [markdown]
# **Exercice 2...**  Extrait exercice livre seconde.
# Représenter la fonction définie sur [-2;8] par :
# > $ f(x)=-0.5×x+1$ sur $[-2;2]$
# > $f(x)=\sqrt{x-2}$ sur $[2;3]$
# > $f(x)=\frac{3}{x}$ sur $[3;8]$

# %% [markdown]
# **Exercice 3 ...**
# Cette fonction est définie sur [0,1], pour $n\geqslant2$ par :
# > $ f(x)=n^{2}x $ si $n\in[0;1/n]$
# > $ f(x)=2n-n^{2}x $ si $n\in[1/n;2/n]$
# > $f(x)=0$ si $x\geqslant2/n$
#
# Vous devez représentez cette fonction pour les dix premières valeurs de n non nulles

# %% [markdown]
# **Exercice 4...**
# Illustrer la méthode de Monte-Carlo.
# Pour approximer $\frac{\pi}{4}$ on simule le choix aléatoire de _n_ points dans le carré unité et on comptabilise ceux qui sont dans le quart de disque trigonométrique. leur fréquence tend vers $\frac{\pi}{4}$ quand *n* devient grand...
# Là, une illustration avec coloriage distinct des points "in" et des points "out" serait une bonne œuvre.

# %% [markdown]
# **Exercice 5**
# L'homme a certes un peu bu... Il est titubant alors qu'il doit traverser un pont long de 10 pas sans rambarde, sans garde fou. Le pont est étroit, large de 4 pas. L'homme part du milieu de l'entrée du pont, il avance soit
# - d'un pas en avant,
# - d'un pas en diagonale sur le côté gauche (soit l'équivalent d'un pas à gauche et d'un pas en avant)
# - ou d'un pas en diagonale sur le côté droit
# et cela au hasard et avec équiprobabilité.
# Il serait souhaitable de simuler une tentative et d'observer avec quelle fréquence il aurait la chance de traverser sur des échantillons de tentatives de plus en plus grand...
# ***Bonus*** sauriez vous illustrer une tentative par une représentation ?
