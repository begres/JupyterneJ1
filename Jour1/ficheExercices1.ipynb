# %% [markdown]
# <h3 style ="color : #0080FF"> Stage Python 21</h3>

# %% [markdown]
# ### Fiche Exercices
#  ---

# %% [markdown]
# **Exercice 1**
# >Créer une fonction qui renvoie n!

# %% [markdown]
# **Exercice 2**
# >Créer une fonction qui renvoie la énième valeurs de la suite de Fibonacci (de premiers termes 0 et 1).

# %% [markdown]
# **Exercice 2**
# >Deux défis graphiques : (avec turtle)
# ![image.png](attachment:image.png)

# %% [markdown]
# **Exercice 4**
# >Que fait ce programme ?
#
# ><pre><python>
# def fct(n) :
#     L=[]
#     while n>-1 :
#         L.append(n)
#         n+=-1
#     return L
# a=int(input('valeur de n ?'))
# print("le .............. de ",a," est :\n",fct(a)) # '\n' permet un retour à la ligne dans l'affichage</code></pre>

# %% [markdown]
# **Exercice 5**
# >Écris un test de primalité sur _n_ utilisant : la parité, la racine carrée de _n_ et la boucle _while_.

# %% [markdown]
# **Exercice 6**
# >Écris une fonction(1) premierPremierPost(_n_) qui renvoie le premier nombre premier _p_ supérieur ou égal à _n_.
# Teste : le premier nombre premier après _n = 42_ est _p = 43_. Quel est le premier nombre premier après _n = 100 000_ ?
# (1) il faudra utiliser la fonction _test de primalité_ …

# %% [markdown]
# **Exercice 7**
# >Donne la liste des 20 premiers nombres premier après 100000.
