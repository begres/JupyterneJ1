# %% [markdown]
# # Des petits problèmes..

# %% [markdown]
# #### Pb1
# Trouver la somme de tous les multiples de 5 ou de 7 inférieurs à 2020.

# %%
#À vous !

# %% [markdown]
# #### Pb2
# En prenant en compte les termes de la suite de Fibonacci (1,1) dont les valeurs ne dépassent pas 4 millions, trouver la somme des termes impairs.

# %%
#À vous !

# %% [markdown]
# #### Pb3
# Quel est le plus grand facteur premier du nombre 20130101 ?

# %%
#À vous !

# %% [markdown]
# #### Pb4
# Quel est le plus grand palindrome que l'on peut obtenir en multipliant un nombre de 4 chiffres avec un nombre de 3 chiffres ?

# %%
#À vous !
