# %% [markdown]
# # Quelques essentiels...

# %% [markdown]
# #### Nous allons manipuler des commandes et des programme écrits en Python. Ici, en ligne vous allez travaillez dirctement sur un notebook.
# Sur votre poste vous travaillerez l'environnement que vous aurez choisi.
# Voici une image de  pyzo pour python...

# %% [markdown]
# les commandes peuvent être écrite directement dans la console shell de pyzo...

# %% [markdown]
# <img src="imgpyzo.png">

# %% [markdown]
# Par exemple sur votre console pyzo vous pourriez entrer, à la suite de l'invite (>>>),les commandes suivantes en validant à chaque fois.

# %% [markdown]
# mais sur ce notebook il vous suffit de cliquer sur
# > **Maj-Entrée** : pour exécuter la cellule, sélectionner la suivante<br>
# > **Ctrl-Entrée** : pour exécuter les cellules sélectionnées<br>
# > **Alt-Entrée** : pour executer et inserer une nouvelle cellule après<br>
#
# Laisser vous tenter et allez y (gaiement ?)

# %%
print ("hello World !")

# %%
2+3

# %% [markdown]
# Jusque là c'est le mode "calculatrice"... introduisons les variables...

# %%
a=4*5

# %%
print (a)

# %%
type(a)    # renvoie le type de la variable

# %%
a = "eggs","spam"   # on modifie la variable et son  type

# %%
print (a)

# %%
type (a)

# %%
def fonct(n):         # 1ère fonction !importance de return! une fonction renvoie toujours un objet
    return n**2-3*n+2

# %%
fonct(10)      # mise en oevre de la fonction "fonct" telle une fonction de math

# %%
fonct(3.1416)

# %%
type(fonct(-3))  # renvoie le type de l'objet

# %%
type(fonct(3.1416))

# %%
type (fonct)

# %%
sqrt(2)

# %%
import math   # TRès important permet de charger un module (~un fichier de fonctions~)

# %%
math.sqrt(2)  # appelle la fonction sqrt du module math

# %%
from math import sqrt   # charge la fonction sqrt du module math

# %%
sqrt(2)      #  appel direct de sqrt (sans préciser son ascendance)

# %%
dir (math)    # permet de connaitre le contenu du module math

# %%
help (math.modf)

# %%
math.modf(math.pi)

# %% [markdown]
# **Exercice 1** : calcule à l'aide des fonctions du module math : 5^10; la partie entière de -6.543, la valeur absolue de  $1-\sqrt{2}$, le reste de la division euclidienne de 3497 par 27 .

# %%
pow(5,10)

# %% [markdown]
# **Exercice 2** : Que fait la fonction 'modf' ?

# %%
math.modf(-6.57)

# %% [markdown]
# ### Les opérations sous python...

# %%
# l'addition 
15+6

# %%
# mais aussi ... (concaténation d'une chaine)
"15"+"eggs"

# %%
type("15"+"eggs")

# %%
#la multiplication
15*6

# %%
# mais aussi...
print (50*"$")

# %%
# La division...
15/3   # ce n'est pas le même résultat sous 3.4 et sous 2.7

# %%
# Mais attention sous Python 2.7 ...15/6 renvoie seulement 2 (division euclidienne)
15/6

# %%
15//6 # sous 3.4 division euclidienne avec //

# %%
15.0/6  # pour forcer sous 2.7 la division décimale  inutile sous 3.4

# %%
#division euclidienne
452//13

# %%
# reste de la division euclidienne
452%13

# %%
# calcul d'une puissance () sans utiliser le module math )
2**8

# %%
2**1024

# %%
type(2**8)

# %%
type(2**1024)

# %%
# mais aussi
math.pow(2,8) #si vous avez importé le module math

# %% [markdown]
# **Exercice 3** : détermine le quotient et le reste de la division euclidienne de 54367 par 13.

# %% [markdown]
# ### Editer un programme...

# %% [raw]
# le programme doit être écrit dans l'éditeur:
# Editez votre programme....

# %%
# par exemple ce programme
print ("bonjour")
nom = input("Comment t'appelles-tu ? ")
print ("bonjour ",nom)

# %% [raw]
# Sous Pyzo : Pour lancer le programme faire Executer / Executer l'onglet courant [Ctrl+E]...
# Le programme est alors lancé dans l'interpréteur Python...

# %% [markdown]
# <img src="excut1.png">

# %% [markdown]
# **Exercice 4**: sur l'interpréteur après exécution du programme rappelez la variable a (avec print par exemple), qu'observez vous ?
#         Comment l'expliquez vous ?

# %% [raw]
# Editez et lancez ce petit programme... que fait-il ?

# %%
for nb in range(100): # la fonction range: elle liste les 100 nombres de 0 à 99. range(a,b) de a à b exclus
    if nb%3 == 0 :
        print (nb)

# %% [markdown]
# **Exercice 5** : Ecrire un programme qui renvoie quotient et reste de la division euclidienne de n par 13 lorsque n
#     varie de 345 à 366 inclus.
